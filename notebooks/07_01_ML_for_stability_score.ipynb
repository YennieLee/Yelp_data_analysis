# %% [markdown]
# # 1. Import Libraries and Load Files

# %%
# basic
import pandas as pd
import numpy as np

# ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import category_encoders as ce
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
from sklearn.model_selection import cross_val_score
import optuna
import shap

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random
import os

SEED = 22
np.random.seed(SEED)
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
df = pd.read_csv('../datasets/business6.csv')

# %% [markdown]
# # 2. Preprocessing for ML

# %% [markdown]
# ### (1) Select Columns for ML

# %%
exclude_cols = [

    # basic restaurant information
    'business_id', 'name', 'attributes', 'categories', 'hours',

    # location information
    'address', 'city', 'postal_code', 'latitude', 'longitude',

    # business hours information
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',

    # cols that used to create stability_score
    'stars', 'stars_std', 'review_count'

            ]

df = df.drop(columns=exclude_cols)

# %% [markdown]
# ### (2) Convert data types

# %%
# -------------------------
# 1. Convert object → int (Boolean Encoding)
# -------------------------

# Columns to convert from string values ("True"/"False") to integer (0/1)
bool_cols = ['a_outdoor_seating', 'a_good_for_group', 'a_good_for_kids', 'a_has_tv', 'a_happy_hour']

# Helper function to convert string boolean values to integer format
def str_to_int_bool(x):
    if pd.isna(x):
        return np.nan   # Keep missing values as NaN (optionally replace with 0 if needed)
    elif str(x).strip().lower() == 'true':
        return 1
    elif str(x).strip().lower() == 'false':
        return 0
    else:
        return np.nan

# Apply conversion to each column and cast to pandas' nullable integer type
for col in bool_cols:
    df[col] = df[col].apply(str_to_int_bool).astype('Int64')

# %%
# -------------------------
# 2. Ordinal Mapping for Noise Level
# -------------------------

# Define the ordered scale: quiet < average < loud < very_loud
noise_mapping = {
    'quiet': 0,
    'average': 1,
    'loud': 2,
    'very_loud': 3
}

# Apply the ordinal mapping
df['a_noise_level'] = df['a_noise_level'].map(noise_mapping)

# %% [markdown]
# ### (3) Impute missing values

# %%
# -------------------------
# 1. a_outdoor_seating ~ a_happy_hour
# -------------------------

# Treat missing values as 0 (meaning the feature does not apply)
cols_bool = ['a_outdoor_seating', 'a_good_for_group', 'a_good_for_kids', 'a_has_tv', 'a_happy_hour']

df[cols_bool] = df[cols_bool].fillna(0).astype(int)

# %%
# -------------------------
# 2. a_alcohol
# -------------------------

# Assign a default value based on nightlife classification
df['a_alcohol'] = np.where(
    df['a_alcohol'].isna(),                                 
    np.where(df['c_nightlife'] == 1, 'full_bar', 'none'),   # If the business is nightlife-focused → assume full bar, otherwise none
    df['a_alcohol']                                         
)

# %%
# -------------------------
# 3. a_ambience
# -------------------------

# Replace missing ambience values with 'unknown'
df['a_ambience'] = df['a_ambience'].fillna('unknown')

# %% [markdown]
# ### (4) Remove Outliers

# %%
# Remove businesses with zero total operating hours

# Record dataset size before filtering
before_count = len(df)

# Filter out rows where total_weekly_hours is zero
df = df[df['total_weekly_hours'] > 0].copy()

# Report how many records were removed
after_count = len(df)
removed = before_count - after_count
print(f"Removed {removed} records ({removed / before_count:.2%})")
# Out:
# Removed 1480 records (7.58%)

# %% [markdown]
# ### (5) Log Transformation

# %%
# Columns selected for log transformation
cols_to_log = [
    'tip_count',
    'neighbor_density'
]

# Visualization (before log transformation)
plt.figure(figsize=(18, 8))
plt.suptitle("Before Log Transformation", fontsize=15, fontweight="bold")

for i, col in enumerate(cols_to_log, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], bins=40, kde=True, color='skyblue')
    plt.title(col)
    plt.xlabel('')
    plt.grid(alpha=0.3)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Apply log transformation with clipping to avoid negative values
for col in cols_to_log:
    df[col] = np.log1p(df[col].clip(lower=0))

# %%
# Visualization (after log transformation)
plt.figure(figsize=(18, 8))
plt.suptitle("After Log Transformation", fontsize=15, fontweight="bold")

for i, col in enumerate(cols_to_log, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], bins=40, kde=True, color='salmon')
    plt.title(f'{col}')
    plt.xlabel('')
    plt.grid(alpha=0.3)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# # 3. Machine Learning

# %%
# -------------------------
# 1. Split data into train and test sets
# -------------------------

X = df.drop("stability_score", axis=1)
y = df["stability_score"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)

# %%
# -------------------------
# 2. Impute missing values
# -------------------------

# --- (1) a_price_range ---
# List of category indicator columns
cat_cols = [
    'c_nightlife', 'c_cafes', 'c_brunch', 'c_sandwich', 'c_american_trad', 'c_american_new',
    'c_italian', 'c_burgers', 'c_mexican', 'c_seafood', 'c_fastfood',
    'c_asian_fusion', 'c_bakeries', 'c_dietary', 'c_other'
]

# Compute median price_range per category based on the training data
cat_medians_train = {
    c: X_train.loc[X_train[c] == 1, 'a_price_range'].median()
    for c in cat_cols
}

# Overall median from the training set (used as fallback)
overall_median = X_train['a_price_range'].median()

# Function to impute missing price_range values
def fill_price(row, cat_medians, overall_median):
    if pd.notna(row['a_price_range']):
        return row['a_price_range']
    
    # Find categories that apply to this business
    cats = [c for c in cat_cols if row[c] == 1]
    vals = [cat_medians[c] for c in cats if not np.isnan(cat_medians[c])]
    
    # If no valid category median exists, use overall median
    if len(vals) == 0:
        val = overall_median
    # If only one category median is available, use it
    elif len(vals) == 1:
        val = vals[0]
    # If multiple medians exist, take the average
    else:
        val = np.mean(vals)
    
    return round(val)

# Apply imputation to training and test sets
X_train['a_price_range'] = X_train.apply(
    fill_price, axis=1, args=(cat_medians_train, overall_median)
).astype(int)

X_test['a_price_range'] = X_test.apply(
    fill_price, axis=1, args=(cat_medians_train, overall_median)  # Use statistics from the training set
).astype(int)

# %%
# --- (2) a_noise_level ---

# Compute median noise_level per category based on the training data
cat_medians_train = {
    c: X_train.loc[X_train[c] == 1, 'a_noise_level'].median()
    for c in cat_cols
}

# Overall median from the training set (used as fallback)
overall_median = X_train['a_noise_level'].median()

# Function to impute missing noise_level values
def fill_noise(row, cat_medians, overall_median):
    if pd.notna(row['a_noise_level']):
        return row['a_noise_level']
    
    # Find categories that apply to this business
    cats = [c for c in cat_cols if row[c] == 1]
    vals = [cat_medians[c] for c in cats if not np.isnan(cat_medians[c])]
    
    # If no valid category median exists, use overall median
    if len(vals) == 0:
        val = overall_median
    # If only one category median is available, use it
    elif len(vals) == 1:
        val = vals[0]
    # If multiple medians exist, take the average
    else:
        val = np.mean(vals)
    
    return round(val)

# Apply imputation to training and test sets
X_train['a_noise_level'] = X_train.apply(
    fill_noise, axis=1, args=(cat_medians_train, overall_median)
).astype(int)

X_test['a_noise_level'] = X_test.apply(
    fill_noise, axis=1, args=(cat_medians_train, overall_median)  # Use statistics from the training set only
).astype(int)

# %%
# --- (3) neighbor_avg_stars ---

# Compute the mean value from the training set
mean_neighbor_stars = X_train['neighbor_avg_stars'].mean()

# Impute missing values using the same mean (train-based)
X_train['neighbor_avg_stars'] = X_train['neighbor_avg_stars'].fillna(mean_neighbor_stars)
X_test['neighbor_avg_stars'] = X_test['neighbor_avg_stars'].fillna(mean_neighbor_stars)

# %%
# -----------------------------
# 3. Target Encoding
# -----------------------------

# categorical columns only
cat_cols = X_train.select_dtypes(include=["object", "category"]).columns.tolist()

encoder = ce.CatBoostEncoder(cols=cat_cols)
X_train_enc = encoder.fit_transform(X_train, y_train)
X_test_enc = encoder.transform(X_test)

# %%
# -----------------------------
# 4. Scaling
# -----------------------------

scaler = StandardScaler()
X_train_enc = scaler.fit_transform(X_train_enc)
X_test_enc = scaler.transform(X_test_enc)

# %%
# -----------------------------
# 5. Evaluate baseline model performance
# -----------------------------
# Define baseline models
SEED = 22
models = {
    "KNN": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(random_state=SEED),
    "SVM": SVR(),
    "Random Forest": RandomForestRegressor(random_state=SEED, n_jobs=1),
    "AdaBoost": AdaBoostRegressor(random_state=SEED),
    "Gradient Boost": GradientBoostingRegressor(random_state=SEED),
    "XGBoost": XGBRegressor(random_state=SEED, verbosity=0, n_jobs=1, deterministic=True),
    "LightGBM": LGBMRegressor(random_state=SEED, n_jobs=1, deterministic=True),
    "CatBoost": CatBoostRegressor(random_state=SEED, verbose=0, thread_count=1)
}

# Evaluate model performance
results = []
for name, model in models.items():
    model.fit(X_train_enc, y_train)
    y_pred = model.predict(X_test_enc)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    results.append({"Model": name, "RMSE": rmse, "MAE": mae, "R²": r2})

# Results DataFrame
results_df = (
    pd.DataFrame(results)
    .sort_values(by="MAE", ascending=True)
    .reset_index(drop=True)
)

display(results_df.style.format({"RMSE": "{:,.2f}", "MAE": "{:,.2f}", "R²": "{:.4f}"}))
# Out:
# c:\Users\toomu\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 지정된 파일을 찾을 수 없습니다
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\toomu\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\toomu\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\toomu\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\toomu\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011218 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3408
# [LightGBM] [Info] Number of data points in the train set: 14443, number of used features: 71
# [LightGBM] [Info] Start training from score 43.590437
# c:\Users\toomu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# <style type="text/css">
# </style>
# <table id="T_8f23a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f23a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8f23a_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_8f23a_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_8f23a_level0_col3" class="col_heading level0 col3" >R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f23a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f23a_row0_col0" class="data row0 col0" >LightGBM</td>
#       <td id="T_8f23a_row0_col1" class="data row0 col1" >11.08</td>
#       <td id="T_8f23a_row0_col2" class="data row0 col2" >9.08</td>
#       <td id="T_8f23a_row0_col3" class="data row0 col3" >0.7045</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f23a_row1_col0" class="data row1 col0" >CatBoost</td>
#       <td id="T_8f23a_row1_col1" class="data row1 col1" >11.12</td>
#       <td id="T_8f23a_row1_col2" class="data row1 col2" >9.08</td>
#       <td id="T_8f23a_row1_col3" class="data row1 col3" >0.7027</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f23a_row2_col0" class="data row2 col0" >Gradient Boost</td>
#       <td id="T_8f23a_row2_col1" class="data row2 col1" >11.13</td>
#       <td id="T_8f23a_row2_col2" class="data row2 col2" >9.12</td>
#       <td id="T_8f23a_row2_col3" class="data row2 col3" >0.7017</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f23a_row3_col0" class="data row3 col0" >Random Forest</td>
#       <td id="T_8f23a_row3_col1" class="data row3 col1" >11.34</td>
#       <td id="T_8f23a_row3_col2" class="data row3 col2" >9.34</td>
#       <td id="T_8f23a_row3_col3" class="data row3 col3" >0.6908</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f23a_row4_col0" class="data row4 col0" >XGBoost</td>
#       <td id="T_8f23a_row4_col1" class="data row4 col1" >11.62</td>
#       <td id="T_8f23a_row4_col2" class="data row4 col2" >9.41</td>
#       <td id="T_8f23a_row4_col3" class="data row4 col3" >0.6753</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f23a_row5_col0" class="data row5 col0" >SVM</td>
#       <td id="T_8f23a_row5_col1" class="data row5 col1" >12.53</td>
#       <td id="T_8f23a_row5_col2" class="data row5 col2" >9.92</td>
#       <td id="T_8f23a_row5_col3" class="data row5 col3" >0.6224</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f23a_row6_col0" class="data row6 col0" >AdaBoost</td>
#       <td id="T_8f23a_row6_col1" class="data row6 col1" >11.98</td>
#       <td id="T_8f23a_row6_col2" class="data row6 col2" >10.22</td>
#       <td id="T_8f23a_row6_col3" class="data row6 col3" >0.6546</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f23a_row7_col0" class="data row7 col0" >Decision Tree</td>
#       <td id="T_8f23a_row7_col1" class="data row7 col1" >16.15</td>
#       <td id="T_8f23a_row7_col2" class="data row7 col2" >12.55</td>
#       <td id="T_8f23a_row7_col3" class="data row7 col3" >0.3721</td>
#     </tr>
#     <tr>
#       <th id="T_8f23a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8f23a_row8_col0" class="data row8 col0" >KNN</td>
#       <td id="T_8f23a_row8_col1" class="data row8 col1" >15.76</td>
#       <td id="T_8f23a_row8_col2" class="data row8 col2" >12.59</td>
#       <td id="T_8f23a_row8_col3" class="data row8 col3" >0.4023</td>
#     </tr>
#   </tbody>
# </table>

# %%
# -------------------------
# 6. Hyperparameter tuning
# -------------------------

# Define an objective function
def objective_cat(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 300, 1000),
        "depth": trial.suggest_int("depth", 4, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 1),
        "random_strength": trial.suggest_float("random_strength", 0.1, 1.0),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "loss_function": "MAE",
        "verbose": 0,
        "random_state": 22
    }

    # Define model
    model = CatBoostRegressor(**params)

    # Fit model
    model.fit(X_train_enc, y_train, eval_set=(X_test_enc, y_test), verbose=0)

    # Predict
    y_pred = model.predict(X_test_enc)

    # Calculate MAE
    mae = mean_absolute_error(y_test, y_pred)
    return mae

# Run optimization
study_cat = optuna.create_study(direction="minimize")
study_cat.optimize(objective_cat, n_trials=100, show_progress_bar=True)

# Show best results
print("Best MAE:", study_cat.best_value)
print("Best Parameters:", study_cat.best_params)

# Train final model
best_params_cat = study_cat.best_params
best_params_cat["loss_function"] = "MAE"
best_cat = CatBoostRegressor(**best_params_cat)
best_cat.fit(X_train_enc, y_train)

# Predict and evaluate on test data
y_pred = best_cat.predict(X_test_enc)

print("\n===== CatBoost (Optimized) =====")
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))

# %%
# -------------------------
# 7. Set base models with best params
# -------------------------

final_cat = CatBoostRegressor(
    iterations = 822, 
    depth = 4, 
    learning_rate = 0.06766196505563632, 
    l2_leaf_reg = 5.389223867779901, 
    bagging_temperature = 0.13716459190149435, 
    random_strength = 0.9516977227869395, 
    border_count = 200, 
    subsample = 0.6728998427883209,
    loss_function = "MAE"
)

# Train final cat model
final_cat.fit(X_train_enc, y_train)

# Predict and evaluate on test data
y_pred = final_cat.predict(X_test_enc)

print("\n===== CatBoost (Optimized) =====")
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
# Out:
# 0:	learn: 16.2511065	total: 23.5ms	remaining: 19.3s
# 1:	learn: 15.5853053	total: 31.8ms	remaining: 13s
# 2:	learn: 14.9804039	total: 36.3ms	remaining: 9.92s
# 3:	learn: 14.4529139	total: 40.8ms	remaining: 8.34s
# 4:	learn: 13.9568063	total: 53ms	remaining: 8.66s
# 5:	learn: 13.5167804	total: 59.9ms	remaining: 8.15s
# 6:	learn: 13.1298811	total: 63.6ms	remaining: 7.41s
# 7:	learn: 12.7934354	total: 67.4ms	remaining: 6.86s
# 8:	learn: 12.4446028	total: 72.9ms	remaining: 6.59s
# 9:	learn: 12.1428404	total: 76.7ms	remaining: 6.23s
# 10:	learn: 11.9397319	total: 80.3ms	remaining: 5.92s
# 11:	learn: 11.7154604	total: 86ms	remaining: 5.81s
# 12:	learn: 11.4872304	total: 90.6ms	remaining: 5.64s
# 13:	learn: 11.2930610	total: 94.6ms	remaining: 5.46s
# 14:	learn: 11.1011480	total: 98.7ms	remaining: 5.31s
# 15:	learn: 10.9451821	total: 104ms	remaining: 5.26s
# 16:	learn: 10.8008316	total: 108ms	remaining: 5.14s
# 17:	learn: 10.6709551	total: 113ms	remaining: 5.03s
# 18:	learn: 10.5542103	total: 118ms	remaining: 5s
# 19:	learn: 10.4342769	total: 122ms	remaining: 4.91s
# 20:	learn: 10.3431010	total: 127ms	remaining: 4.83s
# 21:	learn: 10.2486986	total: 132ms	remaining: 4.78s
# 22:	learn: 10.1565667	total: 136ms	remaining: 4.74s
# 23:	learn: 10.0707682	total: 141ms	remaining: 4.67s
# 24:	learn: 10.0038647	total: 145ms	remaining: 4.62s
# 25:	learn: 9.9375743	total: 152ms	remaining: 4.65s
# 26:	learn: 9.8815139	total: 156ms	remaining: 4.59s
# 27:	learn: 9.8280167	total: 160ms	remaining: 4.55s
# 28:	learn: 9.7839839	total: 167ms	remaining: 4.57s
# 29:	learn: 9.7367690	total: 171ms	remaining: 4.52s
# 30:	learn: 9.6860200	total: 176ms	remaining: 4.48s
# 31:	learn: 9.6432234	total: 182ms	remaining: 4.49s
# 32:	learn: 9.6017971	total: 186ms	remaining: 4.46s
# 33:	learn: 9.5589851	total: 191ms	remaining: 4.42s
# 34:	learn: 9.5208768	total: 196ms	remaining: 4.41s
# 35:	learn: 9.4922111	total: 201ms	remaining: 4.39s
# 36:	learn: 9.4553036	total: 205ms	remaining: 4.36s
# 37:	learn: 9.4215869	total: 210ms	remaining: 4.34s
# 38:	learn: 9.3962190	total: 215ms	remaining: 4.32s
# 39:	learn: 9.3702952	total: 219ms	remaining: 4.29s
# 40:	learn: 9.3410598	total: 224ms	remaining: 4.28s
# 41:	learn: 9.3185436	total: 231ms	remaining: 4.28s
# 42:	learn: 9.2975493	total: 237ms	remaining: 4.3s
# 43:	learn: 9.2756179	total: 245ms	remaining: 4.32s
# 44:	learn: 9.2587622	total: 251ms	remaining: 4.33s
# 45:	learn: 9.2389309	total: 256ms	remaining: 4.33s
# 46:	learn: 9.2211697	total: 262ms	remaining: 4.32s
# 47:	learn: 9.2040716	total: 266ms	remaining: 4.29s
# 48:	learn: 9.1873659	total: 270ms	remaining: 4.26s
# 49:	learn: 9.1702607	total: 276ms	remaining: 4.26s
# 50:	learn: 9.1600897	total: 280ms	remaining: 4.23s
# 51:	learn: 9.1454375	total: 284ms	remaining: 4.2s
# 52:	learn: 9.1324751	total: 288ms	remaining: 4.18s
# 53:	learn: 9.1193555	total: 293ms	remaining: 4.16s
# 54:	learn: 9.1036054	total: 297ms	remaining: 4.14s
# 55:	learn: 9.0908557	total: 301ms	remaining: 4.12s
# 56:	learn: 9.0778873	total: 306ms	remaining: 4.11s
# 57:	learn: 9.0720511	total: 311ms	remaining: 4.09s
# 58:	learn: 9.0622472	total: 315ms	remaining: 4.07s
# 59:	learn: 9.0523868	total: 320ms	remaining: 4.07s
# 60:	learn: 9.0406456	total: 326ms	remaining: 4.06s
# 61:	learn: 9.0280501	total: 333ms	remaining: 4.08s
# 62:	learn: 9.0186111	total: 341ms	remaining: 4.11s
# 63:	learn: 9.0063571	total: 354ms	remaining: 4.19s
# 64:	learn: 9.0009712	total: 362ms	remaining: 4.22s
# 65:	learn: 8.9938677	total: 370ms	remaining: 4.23s
# 66:	learn: 8.9855466	total: 376ms	remaining: 4.23s
# 67:	learn: 8.9756298	total: 382ms	remaining: 4.23s
# 68:	learn: 8.9659176	total: 388ms	remaining: 4.23s
# 69:	learn: 8.9564213	total: 394ms	remaining: 4.23s
# 70:	learn: 8.9474580	total: 401ms	remaining: 4.24s
# 71:	learn: 8.9422391	total: 406ms	remaining: 4.23s
# 72:	learn: 8.9384453	total: 411ms	remaining: 4.22s
# 73:	learn: 8.9302965	total: 416ms	remaining: 4.21s
# 74:	learn: 8.9273891	total: 421ms	remaining: 4.19s
# 75:	learn: 8.9202133	total: 428ms	remaining: 4.2s
# 76:	learn: 8.9140103	total: 434ms	remaining: 4.2s
# 77:	learn: 8.9082218	total: 438ms	remaining: 4.18s
# 78:	learn: 8.9023207	total: 443ms	remaining: 4.17s
# 79:	learn: 8.8991920	total: 449ms	remaining: 4.17s
# 80:	learn: 8.8930092	total: 455ms	remaining: 4.16s
# 81:	learn: 8.8897369	total: 459ms	remaining: 4.14s
# 82:	learn: 8.8846693	total: 466ms	remaining: 4.15s
# 83:	learn: 8.8806286	total: 470ms	remaining: 4.13s
# 84:	learn: 8.8747420	total: 475ms	remaining: 4.12s
# 85:	learn: 8.8696860	total: 481ms	remaining: 4.12s
# 86:	learn: 8.8659383	total: 486ms	remaining: 4.1s
# 87:	learn: 8.8611262	total: 490ms	remaining: 4.09s
# 88:	learn: 8.8559900	total: 497ms	remaining: 4.09s
# 89:	learn: 8.8529253	total: 502ms	remaining: 4.08s
# 90:	learn: 8.8480071	total: 506ms	remaining: 4.07s
# 91:	learn: 8.8414806	total: 513ms	remaining: 4.07s
# 92:	learn: 8.8387494	total: 518ms	remaining: 4.06s
# 93:	learn: 8.8301175	total: 523ms	remaining: 4.05s
# 94:	learn: 8.8266717	total: 529ms	remaining: 4.05s
# 95:	learn: 8.8248743	total: 534ms	remaining: 4.04s
# 96:	learn: 8.8214892	total: 539ms	remaining: 4.03s
# 97:	learn: 8.8182803	total: 545ms	remaining: 4.03s
# 98:	learn: 8.8152429	total: 550ms	remaining: 4.01s
# 99:	learn: 8.8107981	total: 555ms	remaining: 4s
# 100:	learn: 8.8074062	total: 561ms	remaining: 4s
# 101:	learn: 8.7996303	total: 566ms	remaining: 4s
# 102:	learn: 8.7953532	total: 572ms	remaining: 4s
# 103:	learn: 8.7925086	total: 578ms	remaining: 3.99s
# 104:	learn: 8.7895140	total: 583ms	remaining: 3.98s
# 105:	learn: 8.7854410	total: 589ms	remaining: 3.98s
# 106:	learn: 8.7820111	total: 595ms	remaining: 3.97s
# 107:	learn: 8.7786329	total: 600ms	remaining: 3.96s
# 108:	learn: 8.7754812	total: 607ms	remaining: 3.97s
# 109:	learn: 8.7739485	total: 612ms	remaining: 3.96s
# 110:	learn: 8.7718122	total: 617ms	remaining: 3.95s
# 111:	learn: 8.7686587	total: 623ms	remaining: 3.95s
# 112:	learn: 8.7664728	total: 629ms	remaining: 3.95s
# 113:	learn: 8.7631211	total: 636ms	remaining: 3.95s
# 114:	learn: 8.7608731	total: 641ms	remaining: 3.94s
# 115:	learn: 8.7578003	total: 647ms	remaining: 3.94s
# 116:	learn: 8.7542684	total: 652ms	remaining: 3.93s
# 117:	learn: 8.7522230	total: 658ms	remaining: 3.92s
# 118:	learn: 8.7497607	total: 663ms	remaining: 3.92s
# 119:	learn: 8.7479042	total: 669ms	remaining: 3.91s
# 120:	learn: 8.7452739	total: 675ms	remaining: 3.91s
# 121:	learn: 8.7429701	total: 680ms	remaining: 3.9s
# 122:	learn: 8.7407804	total: 687ms	remaining: 3.9s
# 123:	learn: 8.7383579	total: 693ms	remaining: 3.9s
# 124:	learn: 8.7315921	total: 698ms	remaining: 3.89s
# 125:	learn: 8.7293698	total: 705ms	remaining: 3.89s
# 126:	learn: 8.7262656	total: 710ms	remaining: 3.89s
# 127:	learn: 8.7240075	total: 716ms	remaining: 3.88s
# 128:	learn: 8.7214636	total: 722ms	remaining: 3.88s
# 129:	learn: 8.7176507	total: 727ms	remaining: 3.87s
# 130:	learn: 8.7145273	total: 735ms	remaining: 3.88s
# 131:	learn: 8.7118539	total: 743ms	remaining: 3.88s
# 132:	learn: 8.7079444	total: 751ms	remaining: 3.89s
# 133:	learn: 8.7054227	total: 757ms	remaining: 3.88s
# 134:	learn: 8.7029308	total: 763ms	remaining: 3.88s
# 135:	learn: 8.7003121	total: 769ms	remaining: 3.88s
# 136:	learn: 8.6954898	total: 773ms	remaining: 3.87s
# 137:	learn: 8.6939370	total: 781ms	remaining: 3.87s
# 138:	learn: 8.6915916	total: 786ms	remaining: 3.86s
# 139:	learn: 8.6858870	total: 791ms	remaining: 3.85s
# 140:	learn: 8.6841580	total: 800ms	remaining: 3.86s
# 141:	learn: 8.6831139	total: 807ms	remaining: 3.86s
# 142:	learn: 8.6805667	total: 814ms	remaining: 3.87s
# 143:	learn: 8.6775824	total: 819ms	remaining: 3.86s
# 144:	learn: 8.6753305	total: 825ms	remaining: 3.85s
# 145:	learn: 8.6735609	total: 832ms	remaining: 3.85s
# 146:	learn: 8.6714246	total: 838ms	remaining: 3.85s
# 147:	learn: 8.6693401	total: 845ms	remaining: 3.85s
# 148:	learn: 8.6664249	total: 851ms	remaining: 3.84s
# 149:	learn: 8.6621854	total: 856ms	remaining: 3.84s
# 150:	learn: 8.6603646	total: 862ms	remaining: 3.83s
# 151:	learn: 8.6575957	total: 870ms	remaining: 3.83s
# 152:	learn: 8.6531437	total: 879ms	remaining: 3.84s
# 153:	learn: 8.6498060	total: 888ms	remaining: 3.85s
# 154:	learn: 8.6455638	total: 894ms	remaining: 3.85s
# 155:	learn: 8.6427322	total: 899ms	remaining: 3.84s
# 156:	learn: 8.6389981	total: 906ms	remaining: 3.84s
# 157:	learn: 8.6373670	total: 911ms	remaining: 3.83s
# 158:	learn: 8.6362300	total: 917ms	remaining: 3.82s
# 159:	learn: 8.6338510	total: 924ms	remaining: 3.82s
# 160:	learn: 8.6306359	total: 929ms	remaining: 3.81s
# 161:	learn: 8.6284821	total: 934ms	remaining: 3.81s
# 162:	learn: 8.6263259	total: 940ms	remaining: 3.8s
# 163:	learn: 8.6232441	total: 946ms	remaining: 3.79s
# 164:	learn: 8.6198357	total: 951ms	remaining: 3.79s
# 165:	learn: 8.6156185	total: 958ms	remaining: 3.78s
# 166:	learn: 8.6134883	total: 964ms	remaining: 3.78s
# 167:	learn: 8.6119118	total: 971ms	remaining: 3.78s
# 168:	learn: 8.6086428	total: 976ms	remaining: 3.77s
# 169:	learn: 8.6063594	total: 981ms	remaining: 3.76s
# 170:	learn: 8.6044222	total: 987ms	remaining: 3.76s
# 171:	learn: 8.6015479	total: 992ms	remaining: 3.75s
# 172:	learn: 8.5977402	total: 997ms	remaining: 3.74s
# 173:	learn: 8.5954113	total: 1s	remaining: 3.75s
# 174:	learn: 8.5934317	total: 1.01s	remaining: 3.75s
# 175:	learn: 8.5901056	total: 1.02s	remaining: 3.74s
# 176:	learn: 8.5891393	total: 1.02s	remaining: 3.74s
# 177:	learn: 8.5872256	total: 1.03s	remaining: 3.73s
# 178:	learn: 8.5857835	total: 1.04s	remaining: 3.73s
# 179:	learn: 8.5839799	total: 1.04s	remaining: 3.73s
# 180:	learn: 8.5824057	total: 1.05s	remaining: 3.73s
# 181:	learn: 8.5792213	total: 1.06s	remaining: 3.72s
# 182:	learn: 8.5770731	total: 1.06s	remaining: 3.71s
# 183:	learn: 8.5738857	total: 1.07s	remaining: 3.7s
# 184:	learn: 8.5717627	total: 1.07s	remaining: 3.69s
# 185:	learn: 8.5699916	total: 1.08s	remaining: 3.69s
# 186:	learn: 8.5683088	total: 1.09s	remaining: 3.69s
# 187:	learn: 8.5656616	total: 1.09s	remaining: 3.69s
# 188:	learn: 8.5630182	total: 1.1s	remaining: 3.68s
# 189:	learn: 8.5602722	total: 1.1s	remaining: 3.67s
# 190:	learn: 8.5586438	total: 1.11s	remaining: 3.68s
# 191:	learn: 8.5553495	total: 1.12s	remaining: 3.67s
# 192:	learn: 8.5514837	total: 1.13s	remaining: 3.67s
# 193:	learn: 8.5491572	total: 1.13s	remaining: 3.66s
# 194:	learn: 8.5462602	total: 1.14s	remaining: 3.65s
# 195:	learn: 8.5422380	total: 1.14s	remaining: 3.65s
# 196:	learn: 8.5404321	total: 1.15s	remaining: 3.64s
# 197:	learn: 8.5388436	total: 1.15s	remaining: 3.64s
# 198:	learn: 8.5367489	total: 1.16s	remaining: 3.63s
# 199:	learn: 8.5351756	total: 1.17s	remaining: 3.63s
# 200:	learn: 8.5325716	total: 1.17s	remaining: 3.62s
# 201:	learn: 8.5298522	total: 1.18s	remaining: 3.61s
# 202:	learn: 8.5270506	total: 1.18s	remaining: 3.6s
# 203:	learn: 8.5251010	total: 1.19s	remaining: 3.6s
# 204:	learn: 8.5225583	total: 1.19s	remaining: 3.6s
# 205:	learn: 8.5203811	total: 1.2s	remaining: 3.59s
# 206:	learn: 8.5174316	total: 1.21s	remaining: 3.6s
# 207:	learn: 8.5158223	total: 1.22s	remaining: 3.59s
# 208:	learn: 8.5140989	total: 1.22s	remaining: 3.58s
# 209:	learn: 8.5130906	total: 1.23s	remaining: 3.57s
# 210:	learn: 8.5118222	total: 1.23s	remaining: 3.57s
# 211:	learn: 8.5102922	total: 1.24s	remaining: 3.56s
# 212:	learn: 8.5088726	total: 1.25s	remaining: 3.56s
# 213:	learn: 8.5067986	total: 1.25s	remaining: 3.55s
# 214:	learn: 8.5041863	total: 1.26s	remaining: 3.55s
# 215:	learn: 8.5020510	total: 1.26s	remaining: 3.54s
# 216:	learn: 8.4994939	total: 1.27s	remaining: 3.54s
# 217:	learn: 8.4976647	total: 1.27s	remaining: 3.53s
# 218:	learn: 8.4964607	total: 1.28s	remaining: 3.53s
# 219:	learn: 8.4944400	total: 1.29s	remaining: 3.52s
# 220:	learn: 8.4925467	total: 1.29s	remaining: 3.52s
# 221:	learn: 8.4904610	total: 1.3s	remaining: 3.51s
# 222:	learn: 8.4887210	total: 1.3s	remaining: 3.51s
# 223:	learn: 8.4865508	total: 1.31s	remaining: 3.5s
# 224:	learn: 8.4856903	total: 1.32s	remaining: 3.5s
# 225:	learn: 8.4838821	total: 1.32s	remaining: 3.49s
# 226:	learn: 8.4826791	total: 1.33s	remaining: 3.48s
# 227:	learn: 8.4797303	total: 1.33s	remaining: 3.48s
# 228:	learn: 8.4779563	total: 1.34s	remaining: 3.47s
# 229:	learn: 8.4762362	total: 1.34s	remaining: 3.46s
# 230:	learn: 8.4751529	total: 1.35s	remaining: 3.46s
# 231:	learn: 8.4731120	total: 1.36s	remaining: 3.45s
# 232:	learn: 8.4717224	total: 1.36s	remaining: 3.44s
# 233:	learn: 8.4685493	total: 1.37s	remaining: 3.43s
# 234:	learn: 8.4658754	total: 1.37s	remaining: 3.43s
# 235:	learn: 8.4646727	total: 1.38s	remaining: 3.42s
# 236:	learn: 8.4629699	total: 1.38s	remaining: 3.41s
# 237:	learn: 8.4609566	total: 1.39s	remaining: 3.41s
# 238:	learn: 8.4590717	total: 1.4s	remaining: 3.41s
# 239:	learn: 8.4579980	total: 1.4s	remaining: 3.4s
# 240:	learn: 8.4559971	total: 1.41s	remaining: 3.4s
# 241:	learn: 8.4544157	total: 1.42s	remaining: 3.4s
# 242:	learn: 8.4522738	total: 1.43s	remaining: 3.4s
# 243:	learn: 8.4501431	total: 1.44s	remaining: 3.41s
# 244:	learn: 8.4487607	total: 1.45s	remaining: 3.41s
# 245:	learn: 8.4472296	total: 1.45s	remaining: 3.4s
# 246:	learn: 8.4449560	total: 1.46s	remaining: 3.4s
# 247:	learn: 8.4432037	total: 1.47s	remaining: 3.39s
# 248:	learn: 8.4422677	total: 1.47s	remaining: 3.38s
# 249:	learn: 8.4408899	total: 1.48s	remaining: 3.38s
# 250:	learn: 8.4384846	total: 1.48s	remaining: 3.37s
# 251:	learn: 8.4364506	total: 1.49s	remaining: 3.36s
# 252:	learn: 8.4345585	total: 1.49s	remaining: 3.36s
# 253:	learn: 8.4336763	total: 1.5s	remaining: 3.35s
# 254:	learn: 8.4320538	total: 1.5s	remaining: 3.34s
# 255:	learn: 8.4296239	total: 1.51s	remaining: 3.34s
# 256:	learn: 8.4285915	total: 1.51s	remaining: 3.33s
# 257:	learn: 8.4270061	total: 1.52s	remaining: 3.32s
# 258:	learn: 8.4257738	total: 1.52s	remaining: 3.31s
# 259:	learn: 8.4245544	total: 1.53s	remaining: 3.31s
# 260:	learn: 8.4236959	total: 1.54s	remaining: 3.3s
# 261:	learn: 8.4222028	total: 1.54s	remaining: 3.3s
# 262:	learn: 8.4204431	total: 1.55s	remaining: 3.29s
# 263:	learn: 8.4188662	total: 1.55s	remaining: 3.28s
# 264:	learn: 8.4178441	total: 1.56s	remaining: 3.27s
# 265:	learn: 8.4170214	total: 1.56s	remaining: 3.27s
# 266:	learn: 8.4157190	total: 1.57s	remaining: 3.26s
# 267:	learn: 8.4138578	total: 1.57s	remaining: 3.25s
# 268:	learn: 8.4122102	total: 1.58s	remaining: 3.25s
# 269:	learn: 8.4104481	total: 1.59s	remaining: 3.25s
# 270:	learn: 8.4085778	total: 1.59s	remaining: 3.24s
# 271:	learn: 8.4072824	total: 1.6s	remaining: 3.23s
# 272:	learn: 8.4065339	total: 1.6s	remaining: 3.23s
# 273:	learn: 8.4049075	total: 1.61s	remaining: 3.22s
# 274:	learn: 8.4031770	total: 1.62s	remaining: 3.22s
# 275:	learn: 8.4020830	total: 1.62s	remaining: 3.21s
# 276:	learn: 8.3999342	total: 1.63s	remaining: 3.2s
# 277:	learn: 8.3982025	total: 1.63s	remaining: 3.2s
# 278:	learn: 8.3961043	total: 1.64s	remaining: 3.2s
# 279:	learn: 8.3944322	total: 1.65s	remaining: 3.19s
# 280:	learn: 8.3926924	total: 1.65s	remaining: 3.19s
# 281:	learn: 8.3902158	total: 1.66s	remaining: 3.18s
# 282:	learn: 8.3886387	total: 1.67s	remaining: 3.17s
# 283:	learn: 8.3877523	total: 1.67s	remaining: 3.17s
# 284:	learn: 8.3865199	total: 1.68s	remaining: 3.16s
# 285:	learn: 8.3856430	total: 1.68s	remaining: 3.15s
# 286:	learn: 8.3842127	total: 1.69s	remaining: 3.15s
# 287:	learn: 8.3824277	total: 1.7s	remaining: 3.14s
# 288:	learn: 8.3813867	total: 1.7s	remaining: 3.14s
# 289:	learn: 8.3808585	total: 1.71s	remaining: 3.13s
# 290:	learn: 8.3791355	total: 1.71s	remaining: 3.13s
# 291:	learn: 8.3782366	total: 1.72s	remaining: 3.12s
# 292:	learn: 8.3763457	total: 1.73s	remaining: 3.11s
# 293:	learn: 8.3751719	total: 1.73s	remaining: 3.11s
# 294:	learn: 8.3738036	total: 1.74s	remaining: 3.1s
# 295:	learn: 8.3724872	total: 1.74s	remaining: 3.1s
# 296:	learn: 8.3701231	total: 1.75s	remaining: 3.09s
# 297:	learn: 8.3681762	total: 1.76s	remaining: 3.09s
# 298:	learn: 8.3664810	total: 1.77s	remaining: 3.09s
# 299:	learn: 8.3655860	total: 1.78s	remaining: 3.09s
# 300:	learn: 8.3644750	total: 1.79s	remaining: 3.09s
# 301:	learn: 8.3636027	total: 1.79s	remaining: 3.09s
# 302:	learn: 8.3623771	total: 1.8s	remaining: 3.08s
# 303:	learn: 8.3601125	total: 1.81s	remaining: 3.08s
# 304:	learn: 8.3592218	total: 1.81s	remaining: 3.07s
# 305:	learn: 8.3577746	total: 1.82s	remaining: 3.07s
# 306:	learn: 8.3570072	total: 1.82s	remaining: 3.06s
# 307:	learn: 8.3552032	total: 1.83s	remaining: 3.06s
# 308:	learn: 8.3544409	total: 1.84s	remaining: 3.05s
# 309:	learn: 8.3527435	total: 1.85s	remaining: 3.06s
# 310:	learn: 8.3512403	total: 1.86s	remaining: 3.05s
# 311:	learn: 8.3497389	total: 1.86s	remaining: 3.04s
# 312:	learn: 8.3481170	total: 1.87s	remaining: 3.04s
# 313:	learn: 8.3461937	total: 1.87s	remaining: 3.03s
# 314:	learn: 8.3449162	total: 1.88s	remaining: 3.02s
# 315:	learn: 8.3434113	total: 1.89s	remaining: 3.02s
# 316:	learn: 8.3413589	total: 1.89s	remaining: 3.01s
# 317:	learn: 8.3401004	total: 1.9s	remaining: 3s
# 318:	learn: 8.3394093	total: 1.9s	remaining: 3s
# 319:	learn: 8.3378588	total: 1.91s	remaining: 2.99s
# 320:	learn: 8.3370625	total: 1.91s	remaining: 2.98s
# 321:	learn: 8.3357008	total: 1.92s	remaining: 2.98s
# 322:	learn: 8.3342082	total: 1.92s	remaining: 2.97s
# 323:	learn: 8.3335301	total: 1.93s	remaining: 2.97s
# 324:	learn: 8.3315848	total: 1.94s	remaining: 2.96s
# 325:	learn: 8.3300649	total: 1.94s	remaining: 2.96s
# 326:	learn: 8.3292852	total: 1.95s	remaining: 2.95s
# 327:	learn: 8.3280718	total: 1.95s	remaining: 2.94s
# 328:	learn: 8.3266113	total: 1.96s	remaining: 2.94s
# 329:	learn: 8.3256834	total: 1.97s	remaining: 2.93s
# 330:	learn: 8.3240055	total: 1.97s	remaining: 2.92s
# 331:	learn: 8.3216285	total: 1.98s	remaining: 2.92s
# 332:	learn: 8.3196129	total: 1.99s	remaining: 2.93s
# 333:	learn: 8.3182012	total: 2s	remaining: 2.92s
# 334:	learn: 8.3163859	total: 2.01s	remaining: 2.92s
# 335:	learn: 8.3152588	total: 2.01s	remaining: 2.91s
# 336:	learn: 8.3136914	total: 2.02s	remaining: 2.91s
# 337:	learn: 8.3128084	total: 2.03s	remaining: 2.9s
# 338:	learn: 8.3122190	total: 2.03s	remaining: 2.9s
# 339:	learn: 8.3111560	total: 2.04s	remaining: 2.9s
# 340:	learn: 8.3103136	total: 2.05s	remaining: 2.89s
# 341:	learn: 8.3095784	total: 2.05s	remaining: 2.88s
# 342:	learn: 8.3084886	total: 2.06s	remaining: 2.88s
# 343:	learn: 8.3071214	total: 2.07s	remaining: 2.87s
# 344:	learn: 8.3061589	total: 2.07s	remaining: 2.87s
# 345:	learn: 8.3054272	total: 2.08s	remaining: 2.86s
# 346:	learn: 8.3043520	total: 2.09s	remaining: 2.86s
# 347:	learn: 8.3030999	total: 2.09s	remaining: 2.85s
# 348:	learn: 8.3021771	total: 2.1s	remaining: 2.84s
# 349:	learn: 8.3005542	total: 2.1s	remaining: 2.84s
# 350:	learn: 8.2996844	total: 2.11s	remaining: 2.83s
# 351:	learn: 8.2989624	total: 2.12s	remaining: 2.83s
# 352:	learn: 8.2980150	total: 2.12s	remaining: 2.82s
# 353:	learn: 8.2968845	total: 2.13s	remaining: 2.81s
# 354:	learn: 8.2953868	total: 2.13s	remaining: 2.81s
# 355:	learn: 8.2939397	total: 2.14s	remaining: 2.8s
# 356:	learn: 8.2929333	total: 2.14s	remaining: 2.79s
# 357:	learn: 8.2913391	total: 2.15s	remaining: 2.79s
# 358:	learn: 8.2895669	total: 2.16s	remaining: 2.78s
# 359:	learn: 8.2888116	total: 2.16s	remaining: 2.77s
# 360:	learn: 8.2884260	total: 2.17s	remaining: 2.77s
# 361:	learn: 8.2861603	total: 2.17s	remaining: 2.76s
# 362:	learn: 8.2848798	total: 2.18s	remaining: 2.76s
# 363:	learn: 8.2846033	total: 2.19s	remaining: 2.75s
# 364:	learn: 8.2836385	total: 2.19s	remaining: 2.74s
# 365:	learn: 8.2821855	total: 2.2s	remaining: 2.74s
# 366:	learn: 8.2813308	total: 2.2s	remaining: 2.73s
# 367:	learn: 8.2798074	total: 2.21s	remaining: 2.72s
# 368:	learn: 8.2789587	total: 2.21s	remaining: 2.72s
# 369:	learn: 8.2775692	total: 2.22s	remaining: 2.71s
# 370:	learn: 8.2766900	total: 2.22s	remaining: 2.7s
# 371:	learn: 8.2749633	total: 2.23s	remaining: 2.7s
# 372:	learn: 8.2731735	total: 2.23s	remaining: 2.69s
# 373:	learn: 8.2717633	total: 2.24s	remaining: 2.68s
# 374:	learn: 8.2703623	total: 2.25s	remaining: 2.68s
# 375:	learn: 8.2688762	total: 2.25s	remaining: 2.67s
# 376:	learn: 8.2671151	total: 2.26s	remaining: 2.67s
# 377:	learn: 8.2654086	total: 2.27s	remaining: 2.66s
# 378:	learn: 8.2649779	total: 2.27s	remaining: 2.65s
# 379:	learn: 8.2634857	total: 2.28s	remaining: 2.65s
# 380:	learn: 8.2621467	total: 2.28s	remaining: 2.64s
# 381:	learn: 8.2614506	total: 2.29s	remaining: 2.64s
# 382:	learn: 8.2600619	total: 2.29s	remaining: 2.63s
# 383:	learn: 8.2587545	total: 2.3s	remaining: 2.62s
# 384:	learn: 8.2583505	total: 2.31s	remaining: 2.62s
# 385:	learn: 8.2570022	total: 2.31s	remaining: 2.61s
# 386:	learn: 8.2560081	total: 2.32s	remaining: 2.6s
# 387:	learn: 8.2544598	total: 2.32s	remaining: 2.6s
# 388:	learn: 8.2529403	total: 2.33s	remaining: 2.59s
# 389:	learn: 8.2518756	total: 2.34s	remaining: 2.59s
# 390:	learn: 8.2504773	total: 2.34s	remaining: 2.58s
# 391:	learn: 8.2482263	total: 2.35s	remaining: 2.58s
# 392:	learn: 8.2472690	total: 2.36s	remaining: 2.57s
# 393:	learn: 8.2449469	total: 2.37s	remaining: 2.57s
# 394:	learn: 8.2437940	total: 2.37s	remaining: 2.56s
# 395:	learn: 8.2423204	total: 2.38s	remaining: 2.56s
# 396:	learn: 8.2413499	total: 2.38s	remaining: 2.55s
# 397:	learn: 8.2404698	total: 2.39s	remaining: 2.55s
# 398:	learn: 8.2400323	total: 2.4s	remaining: 2.54s
# 399:	learn: 8.2386851	total: 2.4s	remaining: 2.53s
# 400:	learn: 8.2376376	total: 2.41s	remaining: 2.53s
# 401:	learn: 8.2359797	total: 2.41s	remaining: 2.52s
# 402:	learn: 8.2347665	total: 2.42s	remaining: 2.52s
# 403:	learn: 8.2336815	total: 2.43s	remaining: 2.51s
# 404:	learn: 8.2321146	total: 2.43s	remaining: 2.5s
# 405:	learn: 8.2315114	total: 2.44s	remaining: 2.5s
# 406:	learn: 8.2306062	total: 2.45s	remaining: 2.5s
# 407:	learn: 8.2298180	total: 2.46s	remaining: 2.49s
# 408:	learn: 8.2292735	total: 2.46s	remaining: 2.49s
# 409:	learn: 8.2279607	total: 2.47s	remaining: 2.48s
# 410:	learn: 8.2266638	total: 2.48s	remaining: 2.48s
# 411:	learn: 8.2254731	total: 2.48s	remaining: 2.47s
# 412:	learn: 8.2242347	total: 2.49s	remaining: 2.47s
# 413:	learn: 8.2231845	total: 2.5s	remaining: 2.46s
# 414:	learn: 8.2220683	total: 2.5s	remaining: 2.46s
# 415:	learn: 8.2209434	total: 2.51s	remaining: 2.45s
# 416:	learn: 8.2199913	total: 2.52s	remaining: 2.44s
# 417:	learn: 8.2193635	total: 2.52s	remaining: 2.44s
# 418:	learn: 8.2180911	total: 2.53s	remaining: 2.43s
# 419:	learn: 8.2161844	total: 2.54s	remaining: 2.43s
# 420:	learn: 8.2145952	total: 2.54s	remaining: 2.42s
# 421:	learn: 8.2136903	total: 2.55s	remaining: 2.42s
# 422:	learn: 8.2122874	total: 2.56s	remaining: 2.41s
# 423:	learn: 8.2102176	total: 2.56s	remaining: 2.41s
# 424:	learn: 8.2087802	total: 2.57s	remaining: 2.4s
# 425:	learn: 8.2073964	total: 2.58s	remaining: 2.4s
# 426:	learn: 8.2065774	total: 2.59s	remaining: 2.39s
# 427:	learn: 8.2054394	total: 2.59s	remaining: 2.39s
# 428:	learn: 8.2046657	total: 2.6s	remaining: 2.38s
# 429:	learn: 8.2032750	total: 2.61s	remaining: 2.38s
# 430:	learn: 8.2024142	total: 2.62s	remaining: 2.37s
# 431:	learn: 8.2013798	total: 2.63s	remaining: 2.37s
# 432:	learn: 8.2001374	total: 2.63s	remaining: 2.37s
# 433:	learn: 8.1992151	total: 2.64s	remaining: 2.36s
# 434:	learn: 8.1987877	total: 2.65s	remaining: 2.36s
# 435:	learn: 8.1975579	total: 2.66s	remaining: 2.35s
# 436:	learn: 8.1968211	total: 2.67s	remaining: 2.35s
# 437:	learn: 8.1959030	total: 2.67s	remaining: 2.34s
# 438:	learn: 8.1949653	total: 2.68s	remaining: 2.34s
# 439:	learn: 8.1935783	total: 2.69s	remaining: 2.33s
# 440:	learn: 8.1919377	total: 2.69s	remaining: 2.33s
# 441:	learn: 8.1914441	total: 2.7s	remaining: 2.32s
# 442:	learn: 8.1901821	total: 2.71s	remaining: 2.31s
# 443:	learn: 8.1899366	total: 2.71s	remaining: 2.31s
# 444:	learn: 8.1888701	total: 2.74s	remaining: 2.32s
# 445:	learn: 8.1881878	total: 2.74s	remaining: 2.31s
# 446:	learn: 8.1869650	total: 2.75s	remaining: 2.31s
# 447:	learn: 8.1860073	total: 2.77s	remaining: 2.31s
# 448:	learn: 8.1843190	total: 2.77s	remaining: 2.3s
# 449:	learn: 8.1829551	total: 2.78s	remaining: 2.3s
# 450:	learn: 8.1820834	total: 2.79s	remaining: 2.3s
# 451:	learn: 8.1817462	total: 2.8s	remaining: 2.29s
# 452:	learn: 8.1809449	total: 2.81s	remaining: 2.29s
# 453:	learn: 8.1804039	total: 2.81s	remaining: 2.28s
# 454:	learn: 8.1794204	total: 2.82s	remaining: 2.27s
# 455:	learn: 8.1787760	total: 2.83s	remaining: 2.27s
# 456:	learn: 8.1773758	total: 2.84s	remaining: 2.27s
# 457:	learn: 8.1770383	total: 2.84s	remaining: 2.26s
# 458:	learn: 8.1762928	total: 2.85s	remaining: 2.25s
# 459:	learn: 8.1752618	total: 2.86s	remaining: 2.25s
# 460:	learn: 8.1742943	total: 2.87s	remaining: 2.24s
# 461:	learn: 8.1740216	total: 2.88s	remaining: 2.24s
# 462:	learn: 8.1722612	total: 2.88s	remaining: 2.23s
# 463:	learn: 8.1717408	total: 2.89s	remaining: 2.23s
# 464:	learn: 8.1703755	total: 2.9s	remaining: 2.23s
# 465:	learn: 8.1690795	total: 2.9s	remaining: 2.22s
# 466:	learn: 8.1679858	total: 2.91s	remaining: 2.21s
# 467:	learn: 8.1673859	total: 2.92s	remaining: 2.21s
# 468:	learn: 8.1668662	total: 2.93s	remaining: 2.2s
# 469:	learn: 8.1652513	total: 2.93s	remaining: 2.19s
# 470:	learn: 8.1641962	total: 2.94s	remaining: 2.19s
# 471:	learn: 8.1634657	total: 2.95s	remaining: 2.19s
# 472:	learn: 8.1625437	total: 2.95s	remaining: 2.18s
# 473:	learn: 8.1624309	total: 2.96s	remaining: 2.17s
# 474:	learn: 8.1610243	total: 2.97s	remaining: 2.17s
# 475:	learn: 8.1606821	total: 2.98s	remaining: 2.16s
# 476:	learn: 8.1596272	total: 2.98s	remaining: 2.16s
# 477:	learn: 8.1581594	total: 2.99s	remaining: 2.15s
# 478:	learn: 8.1573514	total: 3s	remaining: 2.15s
# 479:	learn: 8.1559012	total: 3s	remaining: 2.14s
# 480:	learn: 8.1547793	total: 3.01s	remaining: 2.13s
# 481:	learn: 8.1536871	total: 3.02s	remaining: 2.13s
# 482:	learn: 8.1527251	total: 3.02s	remaining: 2.12s
# 483:	learn: 8.1520290	total: 3.03s	remaining: 2.12s
# 484:	learn: 8.1510479	total: 3.04s	remaining: 2.11s
# 485:	learn: 8.1504781	total: 3.04s	remaining: 2.1s
# 486:	learn: 8.1497082	total: 3.05s	remaining: 2.1s
# 487:	learn: 8.1490344	total: 3.06s	remaining: 2.09s
# 488:	learn: 8.1485068	total: 3.06s	remaining: 2.09s
# 489:	learn: 8.1473400	total: 3.07s	remaining: 2.08s
# 490:	learn: 8.1466548	total: 3.08s	remaining: 2.08s
# 491:	learn: 8.1455561	total: 3.09s	remaining: 2.07s
# 492:	learn: 8.1442114	total: 3.09s	remaining: 2.06s
# 493:	learn: 8.1433782	total: 3.1s	remaining: 2.06s
# 494:	learn: 8.1428196	total: 3.11s	remaining: 2.05s
# 495:	learn: 8.1419454	total: 3.11s	remaining: 2.04s
# 496:	learn: 8.1408822	total: 3.12s	remaining: 2.04s
# 497:	learn: 8.1396247	total: 3.13s	remaining: 2.03s
# 498:	learn: 8.1391490	total: 3.13s	remaining: 2.03s
# 499:	learn: 8.1379062	total: 3.14s	remaining: 2.02s
# 500:	learn: 8.1372267	total: 3.15s	remaining: 2.02s
# 501:	learn: 8.1360500	total: 3.15s	remaining: 2.01s
# 502:	learn: 8.1353990	total: 3.16s	remaining: 2s
# 503:	learn: 8.1343979	total: 3.17s	remaining: 2s
# 504:	learn: 8.1332948	total: 3.17s	remaining: 1.99s
# 505:	learn: 8.1317832	total: 3.18s	remaining: 1.99s
# 506:	learn: 8.1314364	total: 3.19s	remaining: 1.98s
# 507:	learn: 8.1305848	total: 3.2s	remaining: 1.98s
# 508:	learn: 8.1294136	total: 3.2s	remaining: 1.97s
# 509:	learn: 8.1281685	total: 3.21s	remaining: 1.96s
# 510:	learn: 8.1272851	total: 3.22s	remaining: 1.96s
# 511:	learn: 8.1263736	total: 3.23s	remaining: 1.95s
# 512:	learn: 8.1249053	total: 3.23s	remaining: 1.95s
# 513:	learn: 8.1239954	total: 3.24s	remaining: 1.94s
# 514:	learn: 8.1230086	total: 3.25s	remaining: 1.94s
# 515:	learn: 8.1225070	total: 3.25s	remaining: 1.93s
# 516:	learn: 8.1206716	total: 3.26s	remaining: 1.92s
# 517:	learn: 8.1199690	total: 3.27s	remaining: 1.92s
# 518:	learn: 8.1180267	total: 3.27s	remaining: 1.91s
# 519:	learn: 8.1175104	total: 3.28s	remaining: 1.91s
# 520:	learn: 8.1165010	total: 3.29s	remaining: 1.9s
# 521:	learn: 8.1151106	total: 3.29s	remaining: 1.89s
# 522:	learn: 8.1141572	total: 3.3s	remaining: 1.89s
# 523:	learn: 8.1127297	total: 3.31s	remaining: 1.88s
# 524:	learn: 8.1115551	total: 3.31s	remaining: 1.87s
# 525:	learn: 8.1102276	total: 3.32s	remaining: 1.87s
# 526:	learn: 8.1088525	total: 3.32s	remaining: 1.86s
# 527:	learn: 8.1072153	total: 3.33s	remaining: 1.85s
# 528:	learn: 8.1056398	total: 3.34s	remaining: 1.85s
# 529:	learn: 8.1048001	total: 3.34s	remaining: 1.84s
# 530:	learn: 8.1031754	total: 3.35s	remaining: 1.83s
# 531:	learn: 8.1023781	total: 3.35s	remaining: 1.83s
# 532:	learn: 8.1016153	total: 3.36s	remaining: 1.82s
# 533:	learn: 8.1003597	total: 3.37s	remaining: 1.82s
# 534:	learn: 8.0996253	total: 3.37s	remaining: 1.81s
# 535:	learn: 8.0988507	total: 3.38s	remaining: 1.8s
# 536:	learn: 8.0979726	total: 3.38s	remaining: 1.8s
# 537:	learn: 8.0968924	total: 3.39s	remaining: 1.79s
# 538:	learn: 8.0957118	total: 3.4s	remaining: 1.78s
# 539:	learn: 8.0947978	total: 3.4s	remaining: 1.78s
# 540:	learn: 8.0943658	total: 3.41s	remaining: 1.77s
# 541:	learn: 8.0938037	total: 3.41s	remaining: 1.76s
# 542:	learn: 8.0932745	total: 3.42s	remaining: 1.76s
# 543:	learn: 8.0928187	total: 3.42s	remaining: 1.75s
# 544:	learn: 8.0920001	total: 3.43s	remaining: 1.74s
# 545:	learn: 8.0912310	total: 3.44s	remaining: 1.74s
# 546:	learn: 8.0904471	total: 3.45s	remaining: 1.73s
# 547:	learn: 8.0894889	total: 3.45s	remaining: 1.73s
# 548:	learn: 8.0890334	total: 3.46s	remaining: 1.72s
# 549:	learn: 8.0872601	total: 3.46s	remaining: 1.71s
# 550:	learn: 8.0860001	total: 3.47s	remaining: 1.71s
# 551:	learn: 8.0848664	total: 3.48s	remaining: 1.7s
# 552:	learn: 8.0836826	total: 3.48s	remaining: 1.7s
# 553:	learn: 8.0831802	total: 3.49s	remaining: 1.69s
# 554:	learn: 8.0823401	total: 3.5s	remaining: 1.68s
# 555:	learn: 8.0816406	total: 3.5s	remaining: 1.68s
# 556:	learn: 8.0810129	total: 3.51s	remaining: 1.67s
# 557:	learn: 8.0797913	total: 3.52s	remaining: 1.66s
# 558:	learn: 8.0787535	total: 3.52s	remaining: 1.66s
# 559:	learn: 8.0779240	total: 3.53s	remaining: 1.65s
# 560:	learn: 8.0770923	total: 3.54s	remaining: 1.65s
# 561:	learn: 8.0756466	total: 3.54s	remaining: 1.64s
# 562:	learn: 8.0751893	total: 3.55s	remaining: 1.63s
# 563:	learn: 8.0738692	total: 3.56s	remaining: 1.63s
# 564:	learn: 8.0728731	total: 3.56s	remaining: 1.62s
# 565:	learn: 8.0714050	total: 3.57s	remaining: 1.61s
# 566:	learn: 8.0703720	total: 3.57s	remaining: 1.61s
# 567:	learn: 8.0694386	total: 3.58s	remaining: 1.6s
# 568:	learn: 8.0687802	total: 3.59s	remaining: 1.59s
# 569:	learn: 8.0677159	total: 3.59s	remaining: 1.59s
# 570:	learn: 8.0667188	total: 3.6s	remaining: 1.58s
# 571:	learn: 8.0663709	total: 3.6s	remaining: 1.57s
# 572:	learn: 8.0657892	total: 3.61s	remaining: 1.57s
# 573:	learn: 8.0649331	total: 3.62s	remaining: 1.56s
# 574:	learn: 8.0637527	total: 3.62s	remaining: 1.56s
# 575:	learn: 8.0630845	total: 3.63s	remaining: 1.55s
# 576:	learn: 8.0620298	total: 3.63s	remaining: 1.54s
# 577:	learn: 8.0614578	total: 3.64s	remaining: 1.54s
# 578:	learn: 8.0610681	total: 3.64s	remaining: 1.53s
# 579:	learn: 8.0602764	total: 3.65s	remaining: 1.52s
# 580:	learn: 8.0589042	total: 3.65s	remaining: 1.52s
# 581:	learn: 8.0584748	total: 3.66s	remaining: 1.51s
# 582:	learn: 8.0578527	total: 3.67s	remaining: 1.5s
# 583:	learn: 8.0569198	total: 3.67s	remaining: 1.5s
# 584:	learn: 8.0565036	total: 3.68s	remaining: 1.49s
# 585:	learn: 8.0554758	total: 3.69s	remaining: 1.48s
# 586:	learn: 8.0546288	total: 3.69s	remaining: 1.48s
# 587:	learn: 8.0537080	total: 3.7s	remaining: 1.47s
# 588:	learn: 8.0531326	total: 3.7s	remaining: 1.47s
# 589:	learn: 8.0523045	total: 3.71s	remaining: 1.46s
# 590:	learn: 8.0507404	total: 3.71s	remaining: 1.45s
# 591:	learn: 8.0500071	total: 3.72s	remaining: 1.45s
# 592:	learn: 8.0482430	total: 3.72s	remaining: 1.44s
# 593:	learn: 8.0478587	total: 3.73s	remaining: 1.43s
# 594:	learn: 8.0472926	total: 3.74s	remaining: 1.43s
# 595:	learn: 8.0460816	total: 3.74s	remaining: 1.42s
# 596:	learn: 8.0446812	total: 3.75s	remaining: 1.41s
# 597:	learn: 8.0440245	total: 3.75s	remaining: 1.41s
# 598:	learn: 8.0432896	total: 3.76s	remaining: 1.4s
# 599:	learn: 8.0425402	total: 3.76s	remaining: 1.39s
# 600:	learn: 8.0413008	total: 3.77s	remaining: 1.39s
# 601:	learn: 8.0410706	total: 3.77s	remaining: 1.38s
# 602:	learn: 8.0401012	total: 3.78s	remaining: 1.37s
# 603:	learn: 8.0392057	total: 3.78s	remaining: 1.36s
# 604:	learn: 8.0376490	total: 3.79s	remaining: 1.36s
# 605:	learn: 8.0368483	total: 3.8s	remaining: 1.35s
# 606:	learn: 8.0358011	total: 3.8s	remaining: 1.35s
# 607:	learn: 8.0349546	total: 3.81s	remaining: 1.34s
# 608:	learn: 8.0345980	total: 3.81s	remaining: 1.33s
# 609:	learn: 8.0337341	total: 3.82s	remaining: 1.33s
# 610:	learn: 8.0331756	total: 3.82s	remaining: 1.32s
# 611:	learn: 8.0322853	total: 3.83s	remaining: 1.31s
# 612:	learn: 8.0314761	total: 3.83s	remaining: 1.31s
# 613:	learn: 8.0306564	total: 3.84s	remaining: 1.3s
# 614:	learn: 8.0297702	total: 3.85s	remaining: 1.29s
# 615:	learn: 8.0293792	total: 3.85s	remaining: 1.29s
# 616:	learn: 8.0292050	total: 3.86s	remaining: 1.28s
# 617:	learn: 8.0283802	total: 3.86s	remaining: 1.27s
# 618:	learn: 8.0272019	total: 3.87s	remaining: 1.27s
# 619:	learn: 8.0266887	total: 3.87s	remaining: 1.26s
# 620:	learn: 8.0255814	total: 3.88s	remaining: 1.26s
# 621:	learn: 8.0249124	total: 3.89s	remaining: 1.25s
# 622:	learn: 8.0240189	total: 3.89s	remaining: 1.24s
# 623:	learn: 8.0219980	total: 3.9s	remaining: 1.24s
# 624:	learn: 8.0208615	total: 3.9s	remaining: 1.23s
# 625:	learn: 8.0197962	total: 3.91s	remaining: 1.22s
# 626:	learn: 8.0190318	total: 3.92s	remaining: 1.22s
# 627:	learn: 8.0183118	total: 3.92s	remaining: 1.21s
# 628:	learn: 8.0175531	total: 3.93s	remaining: 1.21s
# 629:	learn: 8.0166776	total: 3.94s	remaining: 1.2s
# 630:	learn: 8.0154793	total: 3.94s	remaining: 1.19s
# 631:	learn: 8.0143908	total: 3.95s	remaining: 1.19s
# 632:	learn: 8.0136637	total: 3.96s	remaining: 1.18s
# 633:	learn: 8.0130250	total: 3.96s	remaining: 1.18s
# 634:	learn: 8.0116152	total: 3.97s	remaining: 1.17s
# 635:	learn: 8.0106604	total: 3.98s	remaining: 1.16s
# 636:	learn: 8.0090591	total: 3.98s	remaining: 1.16s
# 637:	learn: 8.0074264	total: 3.99s	remaining: 1.15s
# 638:	learn: 8.0066508	total: 3.99s	remaining: 1.14s
# 639:	learn: 8.0058699	total: 4s	remaining: 1.14s
# 640:	learn: 8.0048496	total: 4s	remaining: 1.13s
# 641:	learn: 8.0042157	total: 4.01s	remaining: 1.12s
# 642:	learn: 8.0032416	total: 4.02s	remaining: 1.12s
# 643:	learn: 8.0025876	total: 4.02s	remaining: 1.11s
# 644:	learn: 8.0017570	total: 4.03s	remaining: 1.1s
# 645:	learn: 8.0010988	total: 4.03s	remaining: 1.1s
# 646:	learn: 8.0007159	total: 4.04s	remaining: 1.09s
# 647:	learn: 7.9996588	total: 4.05s	remaining: 1.09s
# 648:	learn: 7.9991185	total: 4.05s	remaining: 1.08s
# 649:	learn: 7.9984380	total: 4.06s	remaining: 1.07s
# 650:	learn: 7.9976144	total: 4.06s	remaining: 1.07s
# 651:	learn: 7.9967404	total: 4.07s	remaining: 1.06s
# 652:	learn: 7.9961795	total: 4.08s	remaining: 1.05s
# 653:	learn: 7.9955606	total: 4.09s	remaining: 1.05s
# 654:	learn: 7.9951119	total: 4.09s	remaining: 1.04s
# 655:	learn: 7.9944017	total: 4.1s	remaining: 1.04s
# 656:	learn: 7.9936249	total: 4.11s	remaining: 1.03s
# 657:	learn: 7.9927050	total: 4.11s	remaining: 1.02s
# 658:	learn: 7.9917013	total: 4.12s	remaining: 1.02s
# 659:	learn: 7.9908992	total: 4.13s	remaining: 1.01s
# 660:	learn: 7.9899161	total: 4.13s	remaining: 1.01s
# 661:	learn: 7.9886213	total: 4.14s	remaining: 1s
# 662:	learn: 7.9878104	total: 4.15s	remaining: 995ms
# 663:	learn: 7.9869439	total: 4.16s	remaining: 989ms
# 664:	learn: 7.9862307	total: 4.16s	remaining: 982ms
# 665:	learn: 7.9852701	total: 4.17s	remaining: 976ms
# 666:	learn: 7.9848223	total: 4.17s	remaining: 970ms
# 667:	learn: 7.9838124	total: 4.18s	remaining: 964ms
# 668:	learn: 7.9824616	total: 4.19s	remaining: 958ms
# 669:	learn: 7.9816723	total: 4.19s	remaining: 951ms
# 670:	learn: 7.9805259	total: 4.2s	remaining: 945ms
# 671:	learn: 7.9794710	total: 4.21s	remaining: 939ms
# 672:	learn: 7.9785102	total: 4.21s	remaining: 933ms
# 673:	learn: 7.9777072	total: 4.22s	remaining: 928ms
# 674:	learn: 7.9771221	total: 4.23s	remaining: 921ms
# 675:	learn: 7.9760196	total: 4.24s	remaining: 915ms
# 676:	learn: 7.9752109	total: 4.24s	remaining: 909ms
# 677:	learn: 7.9740301	total: 4.25s	remaining: 903ms
# 678:	learn: 7.9729802	total: 4.26s	remaining: 897ms
# 679:	learn: 7.9722693	total: 4.26s	remaining: 890ms
# 680:	learn: 7.9711395	total: 4.27s	remaining: 884ms
# 681:	learn: 7.9706051	total: 4.28s	remaining: 878ms
# 682:	learn: 7.9696131	total: 4.28s	remaining: 872ms
# 683:	learn: 7.9692684	total: 4.29s	remaining: 865ms
# 684:	learn: 7.9683614	total: 4.29s	remaining: 859ms
# 685:	learn: 7.9680185	total: 4.3s	remaining: 853ms
# 686:	learn: 7.9675900	total: 4.31s	remaining: 847ms
# 687:	learn: 7.9670589	total: 4.32s	remaining: 841ms
# 688:	learn: 7.9667281	total: 4.33s	remaining: 835ms
# 689:	learn: 7.9660052	total: 4.33s	remaining: 829ms
# 690:	learn: 7.9653365	total: 4.34s	remaining: 823ms
# 691:	learn: 7.9640701	total: 4.34s	remaining: 816ms
# 692:	learn: 7.9633341	total: 4.35s	remaining: 810ms
# 693:	learn: 7.9624079	total: 4.36s	remaining: 804ms
# 694:	learn: 7.9616708	total: 4.36s	remaining: 797ms
# 695:	learn: 7.9608070	total: 4.37s	remaining: 791ms
# 696:	learn: 7.9602626	total: 4.38s	remaining: 785ms
# 697:	learn: 7.9590588	total: 4.38s	remaining: 778ms
# 698:	learn: 7.9581616	total: 4.39s	remaining: 772ms
# 699:	learn: 7.9573495	total: 4.39s	remaining: 766ms
# 700:	learn: 7.9568790	total: 4.4s	remaining: 760ms
# 701:	learn: 7.9556814	total: 4.41s	remaining: 753ms
# 702:	learn: 7.9550282	total: 4.41s	remaining: 747ms
# 703:	learn: 7.9547528	total: 4.42s	remaining: 741ms
# 704:	learn: 7.9537285	total: 4.43s	remaining: 735ms
# 705:	learn: 7.9526724	total: 4.43s	remaining: 728ms
# 706:	learn: 7.9515800	total: 4.44s	remaining: 722ms
# 707:	learn: 7.9509400	total: 4.45s	remaining: 716ms
# 708:	learn: 7.9503117	total: 4.46s	remaining: 710ms
# 709:	learn: 7.9496186	total: 4.46s	remaining: 704ms
# 710:	learn: 7.9484532	total: 4.47s	remaining: 697ms
# 711:	learn: 7.9475129	total: 4.47s	remaining: 691ms
# 712:	learn: 7.9473177	total: 4.48s	remaining: 685ms
# 713:	learn: 7.9447415	total: 4.49s	remaining: 679ms
# 714:	learn: 7.9433326	total: 4.49s	remaining: 673ms
# 715:	learn: 7.9422214	total: 4.5s	remaining: 667ms
# 716:	learn: 7.9414300	total: 4.51s	remaining: 661ms
# 717:	learn: 7.9404268	total: 4.52s	remaining: 654ms
# 718:	learn: 7.9398494	total: 4.52s	remaining: 648ms
# 719:	learn: 7.9386256	total: 4.53s	remaining: 642ms
# 720:	learn: 7.9381201	total: 4.54s	remaining: 636ms
# 721:	learn: 7.9372036	total: 4.57s	remaining: 633ms
# 722:	learn: 7.9360340	total: 4.59s	remaining: 629ms
# 723:	learn: 7.9349200	total: 4.62s	remaining: 625ms
# 724:	learn: 7.9338611	total: 4.64s	remaining: 621ms
# 725:	learn: 7.9333652	total: 4.66s	remaining: 616ms
# 726:	learn: 7.9326912	total: 4.67s	remaining: 610ms
# 727:	learn: 7.9314408	total: 4.67s	remaining: 604ms
# 728:	learn: 7.9308598	total: 4.69s	remaining: 598ms
# 729:	learn: 7.9296112	total: 4.71s	remaining: 593ms
# 730:	learn: 7.9284654	total: 4.72s	remaining: 588ms
# 731:	learn: 7.9281202	total: 4.73s	remaining: 582ms
# 732:	learn: 7.9269539	total: 4.74s	remaining: 575ms
# 733:	learn: 7.9260455	total: 4.74s	remaining: 569ms
# 734:	learn: 7.9256301	total: 4.75s	remaining: 562ms
# 735:	learn: 7.9244658	total: 4.76s	remaining: 556ms
# 736:	learn: 7.9238448	total: 4.76s	remaining: 550ms
# 737:	learn: 7.9230291	total: 4.77s	remaining: 543ms
# 738:	learn: 7.9224880	total: 4.78s	remaining: 537ms
# 739:	learn: 7.9216632	total: 4.79s	remaining: 530ms
# 740:	learn: 7.9208289	total: 4.79s	remaining: 524ms
# 741:	learn: 7.9203074	total: 4.8s	remaining: 517ms
# 742:	learn: 7.9199422	total: 4.8s	remaining: 511ms
# 743:	learn: 7.9191258	total: 4.81s	remaining: 504ms
# 744:	learn: 7.9181789	total: 4.82s	remaining: 498ms
# 745:	learn: 7.9175291	total: 4.82s	remaining: 491ms
# 746:	learn: 7.9165234	total: 4.83s	remaining: 485ms
# 747:	learn: 7.9155835	total: 4.83s	remaining: 478ms
# 748:	learn: 7.9147798	total: 4.84s	remaining: 472ms
# 749:	learn: 7.9139876	total: 4.85s	remaining: 465ms
# 750:	learn: 7.9132506	total: 4.86s	remaining: 459ms
# 751:	learn: 7.9122346	total: 4.86s	remaining: 453ms
# 752:	learn: 7.9108395	total: 4.87s	remaining: 446ms
# 753:	learn: 7.9100988	total: 4.87s	remaining: 440ms
# 754:	learn: 7.9092894	total: 4.88s	remaining: 433ms
# 755:	learn: 7.9084821	total: 4.88s	remaining: 426ms
# 756:	learn: 7.9073967	total: 4.89s	remaining: 420ms
# 757:	learn: 7.9059466	total: 4.91s	remaining: 414ms
# 758:	learn: 7.9049845	total: 4.91s	remaining: 408ms
# 759:	learn: 7.9044346	total: 4.92s	remaining: 401ms
# 760:	learn: 7.9035281	total: 4.93s	remaining: 395ms
# 761:	learn: 7.9027867	total: 4.93s	remaining: 388ms
# 762:	learn: 7.9015536	total: 4.94s	remaining: 382ms
# 763:	learn: 7.9002574	total: 4.95s	remaining: 375ms
# 764:	learn: 7.8992491	total: 4.95s	remaining: 369ms
# 765:	learn: 7.8986025	total: 4.96s	remaining: 363ms
# 766:	learn: 7.8978390	total: 4.96s	remaining: 356ms
# 767:	learn: 7.8968783	total: 4.97s	remaining: 349ms
# 768:	learn: 7.8963349	total: 4.97s	remaining: 343ms
# 769:	learn: 7.8959091	total: 4.98s	remaining: 337ms
# 770:	learn: 7.8953276	total: 4.99s	remaining: 330ms
# 771:	learn: 7.8947031	total: 5s	remaining: 324ms
# 772:	learn: 7.8938612	total: 5.01s	remaining: 318ms
# 773:	learn: 7.8927025	total: 5.02s	remaining: 311ms
# 774:	learn: 7.8920055	total: 5.03s	remaining: 305ms
# 775:	learn: 7.8912639	total: 5.03s	remaining: 298ms
# 776:	learn: 7.8902618	total: 5.04s	remaining: 292ms
# 777:	learn: 7.8888481	total: 5.04s	remaining: 285ms
# 778:	learn: 7.8882045	total: 5.05s	remaining: 279ms
# 779:	learn: 7.8874613	total: 5.06s	remaining: 272ms
# 780:	learn: 7.8866298	total: 5.07s	remaining: 266ms
# 781:	learn: 7.8859155	total: 5.08s	remaining: 260ms
# 782:	learn: 7.8849701	total: 5.09s	remaining: 253ms
# 783:	learn: 7.8843186	total: 5.1s	remaining: 247ms
# 784:	learn: 7.8837451	total: 5.11s	remaining: 241ms
# 785:	learn: 7.8827497	total: 5.12s	remaining: 235ms
# 786:	learn: 7.8817430	total: 5.14s	remaining: 228ms
# 787:	learn: 7.8814764	total: 5.15s	remaining: 222ms
# 788:	learn: 7.8807926	total: 5.16s	remaining: 216ms
# 789:	learn: 7.8800572	total: 5.16s	remaining: 209ms
# 790:	learn: 7.8789068	total: 5.17s	remaining: 203ms
# 791:	learn: 7.8781221	total: 5.18s	remaining: 196ms
# 792:	learn: 7.8774978	total: 5.18s	remaining: 190ms
# 793:	learn: 7.8770179	total: 5.19s	remaining: 183ms
# 794:	learn: 7.8762031	total: 5.2s	remaining: 177ms
# 795:	learn: 7.8750593	total: 5.21s	remaining: 170ms
# 796:	learn: 7.8745642	total: 5.21s	remaining: 163ms
# 797:	learn: 7.8740092	total: 5.22s	remaining: 157ms
# 798:	learn: 7.8737785	total: 5.22s	remaining: 150ms
# 799:	learn: 7.8735436	total: 5.23s	remaining: 144ms
# 800:	learn: 7.8731671	total: 5.24s	remaining: 137ms
# 801:	learn: 7.8724285	total: 5.25s	remaining: 131ms
# 802:	learn: 7.8721492	total: 5.26s	remaining: 124ms
# 803:	learn: 7.8716170	total: 5.26s	remaining: 118ms
# 804:	learn: 7.8708215	total: 5.27s	remaining: 111ms
# 805:	learn: 7.8696742	total: 5.28s	remaining: 105ms
# 806:	learn: 7.8688339	total: 5.29s	remaining: 98.3ms
# 807:	learn: 7.8682453	total: 5.29s	remaining: 91.7ms
# 808:	learn: 7.8673726	total: 5.3s	remaining: 85.2ms
# 809:	learn: 7.8661707	total: 5.31s	remaining: 78.7ms
# 810:	learn: 7.8651050	total: 5.32s	remaining: 72.2ms
# 811:	learn: 7.8643460	total: 5.33s	remaining: 65.7ms
# 812:	learn: 7.8639448	total: 5.34s	remaining: 59.1ms
# 813:	learn: 7.8631961	total: 5.35s	remaining: 52.6ms
# 814:	learn: 7.8628145	total: 5.36s	remaining: 46ms
# 815:	learn: 7.8622910	total: 5.37s	remaining: 39.5ms
# 816:	learn: 7.8618561	total: 5.38s	remaining: 32.9ms
# 817:	learn: 7.8612583	total: 5.39s	remaining: 26.4ms
# 818:	learn: 7.8609600	total: 5.4s	remaining: 19.8ms
# 819:	learn: 7.8605979	total: 5.41s	remaining: 13.2ms
# 820:	learn: 7.8602391	total: 5.44s	remaining: 6.63ms
# 821:	learn: 7.8597518	total: 5.46s	remaining: 0us
#
# ===== CatBoost (Optimized) =====
# RMSE: 11.09991881873493
# MAE: 8.67882479076242
# R²: 0.7035200626961076

# %% [markdown]
# # 4. Model Insights

# %%
# -------------------------
# 1. feature importance
# -------------------------

# Get feature importance values
importances = final_cat.get_feature_importance()
features = X_train.columns  # use the same feature order as training data

# Create DataFrame
importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

# Plot top 20 features
plt.figure(figsize=(8,6))
plt.barh(importance_df["Feature"].head(20)[::-1], importance_df["Importance"].head(20)[::-1])
plt.title("CatBoost Feature Importance (Top 20)")
plt.xlabel("Importance")
plt.tight_layout()
plt.show()

# %%
# -------------------------
# 2. SHAP value
# -------------------------

# SHAP for CatBoost
if not isinstance(X_test_enc, pd.DataFrame):
    X_test_enc = pd.DataFrame(X_test_enc, columns=X_test.columns)

explainer = shap.TreeExplainer(final_cat)
shap_values = explainer.shap_values(X_test_enc)

# Summary plot with feature names
shap.summary_plot(
    shap_values,
    X_test_enc, 
    max_display=15,
    show=True
)
# Out:
# C:\Users\toomu\AppData\Local\Temp\ipykernel_11904\19044163.py:13: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(

# %%
# -------------------------
# 3. Detailed SHAP Value Analysis
# -------------------------

# --- (1) a_alcohol ---

cat_col = 'a_alcohol'
shap_col_idx = X_test.columns.get_loc(cat_col)

# Build a DataFrame for SHAP inspection
shap_df = pd.DataFrame({
    cat_col: X_test[cat_col],
    'SHAP Value': shap_values[:, shap_col_idx]
})

# Compute mean SHAP value per category
mean_shap = shap_df.groupby(cat_col)['SHAP Value'].mean()

# Identify the category with the highest impact
highlight_cat = mean_shap.idxmax()

# Assign highlight color only to the top category
colors = ['#004ead' if cat == highlight_cat else '#b1b3c0'
          for cat in shap_df[cat_col].unique()]

# Boxplot visualization
plt.figure(figsize=(6,5))
sns.boxplot(
    data=shap_df,
    x=cat_col,
    y='SHAP Value',
    palette=colors
)

# Formatting
plt.title("SHAP Value by Alcohol Availability", fontsize=12, weight='bold')
plt.ylabel("SHAP Value")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"🔹 Highlighted category: {highlight_cat}")
# Out:
# C:\Users\toomu\AppData\Local\Temp\ipykernel_11904\330089346.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# 🔹 Highlighted category: none

# %%
# --- (2) category_variety ---

# Convert shap_values to a pure NumPy array
if hasattr(shap_values, "values"):  
    shap_array = shap_values.values
else:                                
    shap_array = np.array(shap_values)

# Ensure X_test_enc is a DataFrame
if not isinstance(X_test_enc, pd.DataFrame):
    X_test_enc = pd.DataFrame(X_test_enc, columns=X_test.columns)

# Build a DataFrame for SHAP analysis
shap_df = pd.DataFrame({
    'category_variety': X_test_enc['category_variety'],
    'shap_value': shap_array[:, X_test_enc.columns.get_loc('category_variety')]
})

# Calculate mean SHAP value by category variety level
shap_trend = (
    shap_df.groupby('category_variety')['shap_value']
           .mean()
           .reset_index()
           .sort_values('category_variety')
)

# Plot SHAP trend as a line graph
plt.figure(figsize=(6,5))
plt.plot(
    shap_trend['category_variety'],
    shap_trend['shap_value'],
    marker='o',
    linestyle='-',
    color='#004ead'
)

plt.title("SHAP Value by Category Variety", fontsize=13)
plt.xlabel("Category Variety")
plt.ylabel("Mean SHAP Value")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
